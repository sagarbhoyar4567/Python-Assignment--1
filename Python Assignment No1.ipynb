# %% [markdown]
# ## Assignment No 1 : Python Basics - Assignment

# %% [markdown]
# ##### Name : Sagar Bhoyar
# ##### Batch : cohort 138

# %% [raw]
# Que 1. Simple Message: Store a message in a variable, and then print that message.

# %%
message = 'I am working on the Python assignment no 1'
print(message)
# Out:
# I am working on the Python assignment no 1

# %% [raw]
# Que 2. Store a message in a variable and print that message. Then change the
# value of your variable to a new message and print the new message.

# %%
message1 = 'I am working on the Python assignment no 1'
print(message1)
# Out:
# I am working on the Python assignment no 1

# %%
message1= 'I have completed Que No 1 and now working on Que No.2'
print(message1)
# Out:
# I have completed Que No 1 and now working on Que No.2

# %% [raw]
# Que 3. Store a person’s name in a variable and print a message to that person.
# Your message should be simple, such as, “Hello Eric, would you like to
# learn some Python today?”

# %%
pname='sagar'
print(f'"hello {pname},would you like to learn some Python today?"')
print('"hello {},would you like to learn some python today?"'.format(pname))
# Out:
# "hello sagar,would you like to learn some Python today?"
# "hello sagar,would you like to learn some python today?"

# %% [raw]
# Que 4. Find a quote from a famous person you admire. Print the quote and the
# name of its author. Your output should look something like the following,
# including the quotation marks: Albert Einstein once said, “A person who
# never made a mistake never tried anything new.”

# %%
print('Oscar Wilde once said "Be yourself everyone else is already taken."')
# Out:
# Oscar Wilde once said "Be yourself everyone else is already taken."

# %% [raw]
# Que 5. Repeat Exercise 4, but this time store the famous person’s name in a
# variable called famous_person. Then compose your message and store it in
# a new variable called message. Print your message.

# %%
famous_person='Oscar Wilde'
quote_message='"Be yourself everyone else is already taken."'
print(f'{famous_person} once said,{quote_message}')
# Out:
# Oscar Wilde once said,"Be yourself everyone else is already taken."

# %% [raw]
# Que 6. Write addition, subtraction, multiplication, and division operations that
# each result in the number 8. Be sure to enclose your operations in print
# statements to see the results. You should create four lines that look like
# this:    print (5 + 3)
# Your output should simply be four lines with the number 8 appearing once
# on each line.

# %%
#name : sagar Bhoyar 
#date : 23rd Feb 2026
# this perticular program performing summation,subtraction,multiplication and division which will have final result 8

print(1+7)
print(10-2)
print(4*2)
print(int(16/2))
# Out:
# 8
# 8
# 8
# 8

# %% [raw]
# Que 7. Store your favourite number in a variable. Then, using that variable, create
# a message that reveals your favourite number. Print that message.

# %%
#name : sagar Bhoyar 
#date : 23rd Feb 2026
# this perticular program capturing the favourite number and printing the captured number with the message

fav_number = 7
print('my favourite number is {}'.format(fav_number))
print(f'my favourite number is {fav_number}')
# Out:
# my favourite number is 7
# my favourite number is 7

# %% [raw]
# Que 8. Choose two of the programs you’ve written and add at least one comment
# to each. If you don’t have anything specific to write because your programs
# are too simple at this point, just add your name and the current date at the
# top of each program file. Then write one sentence describing what the
# program does.

# %% [raw]
# I did this activity for que no 7 and que no 6

# %% [raw]
# Que 9. Store the names of a few of your friends in a list called names. Print each
# person’s name by accessing each element in the list, one at a time.

# %%
friends=['Sagar','Ricky','Stuart','Allen','MSD','Sachin','Virat']

# %%
for i in friends:
    print(i)
# Out:
# Sagar
# Ricky
# Stuart
# Allen
# MSD
# Sachin
# Virat

# %%
print(friends[0])
print(friends[1])
print(friends[2])
print(friends[3])
print(friends[4])
print(friends[5])
print(friends[6])
# Out:
# Sagar
# Ricky
# Stuart
# Allen
# MSD
# Sachin
# Virat

# %% [raw]
# Que 10. Start with the list you used in Exercise 9, but instead of just printing each
# person’s name, print a message to them. The text of each message should
# be the same, but each message should be personalized with the person’s
# name.

# %%
for i in friends:
    print(i+' is my one of the oldest childhood friend')
# Out:
# Sagar is my one of the oldest childhood friend
# Ricky is my one of the oldest childhood friend
# Stuart is my one of the oldest childhood friend
# Allen is my one of the oldest childhood friend
# MSD is my one of the oldest childhood friend
# Sachin is my one of the oldest childhood friend
# Virat is my one of the oldest childhood friend

# %%
print(f'{friends[0]} is my one of the oldest childhood friend')
print(f'{friends[1]} is my one of the oldest childhood friend')
print(f'{friends[2]} is my one of the oldest childhood friend')
print(f'{friends[3]} is my one of the oldest childhood friend')
print(f'{friends[4]} is my one of the oldest childhood friend')
print(f'{friends[5]} is my one of the oldest childhood friend')
print(f'{friends[6]} is my one of the oldest childhood friend')
# Out:
# Sagar is my one of the oldest childhood friend
# Ricky is my one of the oldest childhood friend
# Stuart is my one of the oldest childhood friend
# Allen is my one of the oldest childhood friend
# MSD is my one of the oldest childhood friend
# Sachin is my one of the oldest childhood friend
# Virat is my one of the oldest childhood friend

# %% [raw]
# Que 11. Think of your favourite mode of transportation, such as a motorcycle or a
# car, and make a list that stores several examples. Use your list to print a
# series of statements about these items, such as “I would like to own a
# Honda motorcycle.”

# %%
fav_tran=['Car','motorcycle','jet']
print(f'"I would like to own a audi {fav_tran[0]}"')
print(f'"I would like to own a Suzuki {fav_tran[1]}"')
print(f'"I would like to own a private {fav_tran[2]}"')
# Out:
# "I would like to own a audi Car"
# "I would like to own a Suzuki motorcycle"
# "I would like to own a private jet"

# %%
for i in fav_tran:
    print('"I would like to own a audi '+ i +'Car"')
# Out:
# "I would like to own a audi CarCar"
# "I would like to own a audi motorcycleCar"
# "I would like to own a audi jetCar"
